# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, timedelta
from collections import Counter

df = pd.read_csv('data/matches.csv')

# %%
map_ = 'Land Nomad (Random civs)'
map_df = df[df['map'] == map_]

# %%
all_player_games = df['w1'].values.tolist() + \
    df['w2'].values.tolist() + \
    df['w3'].values.tolist() + \
    df['w4'].values.tolist() + \
    df['l1'].values.tolist() + \
    df['l2'].values.tolist() + \
    df['l3'].values.tolist() + \
    df['l4'].values.tolist()

player_game_count = Counter(all_player_games)
player_game_count
# Out:
# Counter({'adirath': 2804,
#          'Ju$TK!Dd!nG': 2617,
#          'Saracen': 2439,
#          'MODI': 1964,
#          'newisyou': 1926,
#          'Livi': 1870,
#          'addu': 1674,
#          'Plan B': 1615,
#          'TRush': 1443,
#          'FraGStaR': 1439,
#          'Sephiroth': 1364,
#          '🥭bush': 1194,
#          'Valar': 1094,
#          'ForeRuthless': 1080,
#          'Bondulkar': 1023,
#          'CHICKEN': 991,
#          'BraveHeart': 955,
#          'dopefish': 931,
#          'Blitz': 904,
#          'SuLTaN': 892,
#          'wArDaDdY': 856,
#          'Mirror': 854,
#          'Tinikeya': 844,
#          'Sargun': 835,
#          'Deadkorpse': 827,
#          'bosedk1': 787,
#          'Himansu': 786,
#          'ABHI': 734,
#          'Delusion9': 729,
#          'THUNDER': 714,
#          'Kappa': 710,
#          'Shadeslayer II': 707,
#          'CrazyGuY': 684,
#          'arjya13': 663,
#          'Aragorn': 644,
#          'Royal': 632,
#          'RedViper': 620,
#          'Aragornn': 612,
#          'Avenger': 589,
#          'Thiru': 572,
#          'Oldman0007': 566,
#          'DOOMSTER': 561,
#          'HELLRAZER': 516,
#          'peppapig2108': 511,
#          'MrWrong': 508,
#          'talentbutnofarm': 490,
#          'Water': 390,
#          'CHARITH': 390,
#          'JayMystic': 374,
#          'Sigma Grindset': 370,
#          'JAYRAJ': 368,
#          'Ancalagon': 336,
#          'KhalDrogo': 330,
#          'gelf': 303,
#          nan: 277,
#          'Lathkore': 246,
#          'AsOcA': 224,
#          'PoinDexter': 220,
#          'Afterlife': 216,
#          'pHANTOM': 201,
#          'AgentP97': 196,
#          'n0chanc3': 189,
#          'noobnoob': 182,
#          'गुरुत्वाकर्षण': 171,
#          'franc': 157,
#          'cr717': 152,
#          'ddk': 150,
#          'Lucky23': 149,
#          'capeBoysNoob': 134,
#          'dst': 116,
#          'OS': 103,
#          'fenrir05': 103,
#          'Wildling': 102,
#          'Chacha': 97,
#          'Amadeus': 97,
#          'Av3stan': 96,
#          'Bomberman7991': 96,
#          'Simba': 90,
#          'Satanicwarhamster': 87,
#          'Alexander8507': 76,
#          'scarecrow': 75,
#          'Apu': 75,
#          'sid': 67,
#          'Fish Curry': 63,
#          'FraGSitauX': 62,
#          'drgameher': 60,
#          'keysersoze': 58,
#          'The SILENT MONK': 55,
#          'dragonstar1233': 52,
#          'Morty': 51,
#          'Dranzer13': 47,
#          'harshit': 44,
#          'steelskin': 43,
#          'ucchash94': 41,
#          'Nicco': 36,
#          'Phantom': 35,
#          'Vegeta9999': 34,
#          'jOkEs On YoU': 32,
#          'Rohan': 30,
#          'SMR': 25,
#          'link.chaos': 23,
#          'Storm': 22,
#          'himansu': 20,
#          'motava': 20,
#          'ThirtiethBog219': 20,
#          'Yugeengimli': 18,
#          'WackieChan': 18,
#          'Anca': 18,
#          'Diabloz': 18,
#          'Jesterkori': 17,
#          'Legion64': 15,
#          'Slayer': 15,
#          'LlamaToast 🏴☠': 14,
#          'shrp': 13,
#          'Hitman': 13,
#          'rsalgut': 11,
#          'leo.abnv': 10,
#          'Maximus': 10,
#          'chaosrd': 10,
#          'kaos': 10,
#          'cloudriders': 9,
#          'andrabi': 8,
#          'MachPatel': 8,
#          'billuboss': 7,
#          'NileshJavar': 7,
#          'Strider': 6,
#          'Comrade': 6,
#          'vinay24': 5,
#          'rogganwololo': 5,
#          'MadMax': 5,
#          'prof': 5,
#          'Sniper': 4,
#          'Mr.LoVe': 4,
#          'Asterix': 3,
#          'HenryX': 3,
#          'Bangbang': 3,
#          'deepak.sharma.ji': 3,
#          'SkuLLXD': 3,
#          'TheHappyBoar': 2,
#          'goko': 2,
#          'threeeyedraven': 2,
#          'BombayGypsy': 2,
#          'Lifehack': 2,
#          'basshunteraoe': 2,
#          'HistoryNerd': 2,
#          'Shoumo': 2,
#          'riddist': 2,
#          'Ikka Stuff': 1,
#          'nemes1s': 1,
#          'Srini Mama': 1,
#          'rafale360': 1,
#          '💥Smokeu4joke': 1,
#          'cyanide': 1,
#          'veralasata': 1,
#          'ch0r': 1,
#          'thaimadz': 1,
#          'bavinGelson': 1,
#          'Zaid Noob': 1,
#          'avnish1': 1,
#          'samudragupta2904': 1,
#          'tasmaniandevil21': 1,
#          'WhiteSmith': 1,
#          'stealthyChakram': 1,
#          'Beelzebub': 1,
#          'Plan C': 1,
#          'MarjiManRTS': 1,
#          'abhinandankarwa': 1,
#          'bharathkumar539': 1,
#          'eKkO': 1})

# %%
map_df
# Out:
#       match_id        date year_month                       map      w1  \
# 7       856361  2024-02-08    2024-02  Land Nomad (Random civs)    addu
# 25      853987  2024-02-05    2024-02  Land Nomad (Random civs)   Thiru
# 44      852714  2024-02-04    2024-02  Land Nomad (Random civs)  Plan B
# 60      851770  2024-02-03    2024-02  Land Nomad (Random civs)  Plan B
# 75      850261  2024-02-02    2024-02  Land Nomad (Random civs)   Thiru
# ...        ...         ...        ...                       ...     ...
# 5498    474646  2022-07-05    2022-07  Land Nomad (Random civs)  Mirror
# 5530    472874  2022-07-01    2022-07  Land Nomad (Random civs)     ddk
# 5582    470022  2022-06-23    2022-06  Land Nomad (Random civs)    addu
# 5606    468780  2022-06-20    2022-06  Land Nomad (Random civs)  Mirror
# 5615    468050  2022-06-18    2022-06  Land Nomad (Random civs)    addu
#
#              w2            w3              w4             l1          l2  ...  \
# 7     Afterlife          Livi       Bondulkar          Thiru   JayMystic  ...
# 25      MrWrong  ForeRuthless        newisyou  Bomberman7991  Deadkorpse  ...
# 44       SuLTaN       Avenger         Himansu        bosedk1  Deadkorpse  ...
# 60      Avenger   Ju$TK!Dd!nG            ABHI         Mirror       Rohan  ...
# 75        🥭bush     Sephiroth      BraveHeart             OS      Plan B  ...
# ...         ...           ...             ...            ...         ...  ...
# 5498        ddk       adirath  Shadeslayer II       noobnoob       Kappa  ...
# 5530    Saracen      FraGStaR         Aragorn        arjya13  Vegeta9999  ...
# 5582    THUNDER   Ju$TK!Dd!nG         adirath          Thiru     arjya13  ...
# 5606     Sargun          Livi     Ju$TK!Dd!nG          Thiru        gelf  ...
# 5615     Mirror      newisyou         adirath          Kappa     Saracen  ...
#
#      w4_nr l1_or  l2_or  l3_or  l4_or  l1_nr  l2_nr  l3_nr  l4_nr    map_only
# 7      557  1846   1638   1538    420   1830   1622   1522    404  Land Nomad
# 25     661  1657   1534   1108    904   1640   1517   1091    887  Land Nomad
# 44    1110  1647   1638   1172    589   1626   1617   1151    568  Land Nomad
# 60     230  1655    718    645    528   1637    700    627    510  Land Nomad
# 75     961  1994   1452   1118    861   1967   1425   1091    834  Land Nomad
# ...    ...   ...    ...    ...    ...    ...    ...    ...    ...         ...
# 5498   873  1816   1676    818    341   1800   1660    802    325  Land Nomad
# 5530   497  1382   1138    633    606   1368   1124    619    592  Land Nomad
# 5582   873  1632   1524   1326    641   1617   1509   1311    626  Land Nomad
# 5606  1097  1649   1367   1035    812   1634   1352   1020    797  Land Nomad
# 5615   764  1659   1344   1167   1030   1641   1326   1149   1012  Land Nomad
#
# [267 rows x 29 columns]

# %%
all_players = list(set(
                    map_df['w1'].values.tolist() +
                    map_df['w2'].values.tolist() +
                    map_df['w3'].values.tolist() +
                    map_df['w4'].values.tolist() +
                    map_df['l1'].values.tolist() +
                    map_df['l2'].values.tolist() +
                    map_df['l3'].values.tolist() +
                    map_df['l4'].values.tolist()
                    ))
all_players = list(filter(pd.notna, all_players))

# %%
stats = []
for player in all_players:
    won = len(map_df[
                        (map_df['w1'] == player) |
                        (map_df['w2'] == player) |
                        (map_df['w3'] == player) |
                        (map_df['w4'] == player)
                        ].index)
    lost = len(map_df[
                        (map_df['l1'] == player) |
                        (map_df['l2'] == player) |
                        (map_df['l3'] == player) |
                        (map_df['l4'] == player)
                        ].index)
    play_rate = round((won+lost) * 100 / player_game_count[player], 2)
    win_rate = round(won * 100 / (won+lost), 2)
    if won+lost > 0:
        stats.append({
            'player': player,
            'total': won+lost,
            'play_rate': play_rate, 
            'won': won,
            'lost': lost,
            'win_rate': win_rate
        })
stats_df = pd.DataFrame(stats).sort_values(by='win_rate', ascending=False)
results = stats_df[stats_df['total'] >= 10].reset_index(drop=True)
results
# Out:
#              player  total  play_rate  won  lost  win_rate
# 0          DOOMSTER     14       2.50   10     4     71.43
# 1              addu     40       2.39   28    12     70.00
# 2             Water     23       5.90   16     7     69.57
# 3         HELLRAZER     24       4.65   15     9     62.50
# 4         JayMystic     20       5.35   12     8     60.00
# 5        PoinDexter     15       6.82    9     6     60.00
# 6      ForeRuthless     49       4.54   29    20     59.18
# 7              ABHI     24       3.27   14    10     58.33
# 8             Thiru     19       3.32   11     8     57.89
# 9          FraGStaR     52       3.61   30    22     57.69
# 10        Bondulkar     72       7.04   41    31     56.94
# 11          adirath    129       4.60   73    56     56.59
# 12          Aragorn     18       2.80   10     8     55.56
# 13        Sephiroth     47       3.45   26    21     55.32
# 14         Lathkore     11       4.47    6     5     54.55
# 15        Delusion9     26       3.57   14    12     53.85
# 16           Plan B     77       4.77   41    36     53.25
# 17             MODI     71       3.62   37    34     52.11
# 18         newisyou     73       3.79   38    35     52.05
# 19          Himansu     50       6.36   26    24     52.00
# 20          Saracen     78       3.20   40    38     51.28
# 21         wArDaDdY     39       4.56   20    19     51.28
# 22   Shadeslayer II     40       5.66   20    20     50.00
# 23            AsOcA     14       6.25    7     7     50.00
# 24          CHICKEN     38       3.83   19    19     50.00
# 25          MrWrong     30       5.91   15    15     50.00
# 26          THUNDER     40       5.60   20    20     50.00
# 27       BraveHeart     58       6.07   29    29     50.00
# 28        KhalDrogo     12       3.64    6     6     50.00
# 29             Livi     75       4.01   37    38     49.33
# 30            🥭bush     55       4.61   27    28     49.09
# 31       Deadkorpse     33       3.99   16    17     48.48
# 32     peppapig2108     21       4.11   10    11     47.62
# 33         Aragornn     39       6.37   18    21     46.15
# 34         dopefish     26       2.79   12    14     46.15
# 35          Avenger     24       4.07   11    13     45.83
# 36            Royal     35       5.54   16    19     45.71
# 37  talentbutnofarm     29       5.92   13    16     44.83
# 38           Sargun     25       2.99   11    14     44.00
# 39            TRush     64       4.44   28    36     43.75
# 40          pHANTOM     16       7.96    7     9     43.75
# 41            Blitz     39       4.31   17    22     43.59
# 42          bosedk1     23       2.92   10    13     43.48
# 43      Ju$TK!Dd!nG     97       3.71   42    55     43.30
# 44           SuLTaN     43       4.82   18    25     41.86
# 45           Mirror     24       2.81   10    14     41.67
# 46    गुरुत्वाकर्षण     10       5.85    4     6     40.00
# 47         Tinikeya     30       3.55   12    18     40.00
# 48          CHARITH     14       3.59    5     9     35.71
# 49       Oldman0007     20       3.53    7    13     35.00
# 50            Valar     26       2.38    8    18     30.77
# 51           JAYRAJ     13       3.53    4     9     30.77
# 52   Sigma Grindset     12       3.24    3     9     25.00
