# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, timedelta
from collections import Counter

df = pd.read_csv('data/matches.csv')

# %%
map_ = 'Land Nomad (Random civs)'
map_df = df[df['map'] == map_]

# %%
all_player_games = df['w1'].values.tolist() + \
    df['w2'].values.tolist() + \
    df['w3'].values.tolist() + \
    df['w4'].values.tolist() + \
    df['l1'].values.tolist() + \
    df['l2'].values.tolist() + \
    df['l3'].values.tolist() + \
    df['l4'].values.tolist()

player_game_count = Counter(all_player_games)
# player_game_count
# Out:
# Counter({'adirath': 3963,
#          'Ju$TK!Dd!nG': 3561,
#          'Saracen': 2795,
#          'newisyou': 2795,
#          'MODI': 2738,
#          'Plan B': 2266,
#          'Livi': 2266,
#          'TRush': 1997,
#          'addu': 1903,
#          'FraGStaR': 1889,
#          'ForeRuthless': 1664,
#          'wArDaDdY': 1588,
#          'Valar': 1563,
#          'AMMbush': 1537,
#          'New Player': 1473,
#          'Sephiroth': 1469,
#          'BraveHeart': 1418,
#          'SuLTaN': 1363,
#          'Himansu': 1291,
#          'Aragornn': 1255,
#          'CHICKEN': 1216,
#          'JayMystic': 1089,
#          'Royal': 1059,
#          'peppapig2108': 1040,
#          'Avenger': 1032,
#          'dopefish': 1020,
#          'Delusion9': 1012,
#          'THUNDER': 993,
#          'Shadeslayer II': 975,
#          'Blitz': 971,
#          'MrWrong': 947,
#          'Mirror': 927,
#          'Deadkorpse': 885,
#          'ABHI': 864,
#          'Kappa': 844,
#          'Tinikeya': 844,
#          'bosedk1': 837,
#          'Sargun': 835,
#          'CrazyGuY': 833,
#          'Water': 811,
#          'DOOMSTER': 787,
#          'Thiru': 707,
#          'RedViper': 683,
#          'Oldman0007': 683,
#          'arjya13': 663,
#          'raichoooo!!!!!': 660,
#          'Aragorn': 644,
#          'HELLRAZER': 563,
#          'OS': 529,
#          'talentbutnofarm': 523,
#          'KhalDrogo': 493,
#          'ancalagon100': 470,
#          'CHARITH': 429,
#          'Afterlife': 402,
#          'Brother VK': 385,
#          'Lathkore': 384,
#          'Sigma Grindset': 370,
#          nan: 349,
#          'Fenrir': 333,
#          'Morty': 331,
#          'gelf': 303,
#          'AgentP97': 283,
#          'noobnoob': 238,
#          'pHANTOM': 236,
#          'AsOcA': 224,
#          'PoinDexter': 221,
#          'गुरुत्वाकर्षण': 218,
#          'bomberman': 165,
#          'franc': 157,
#          'cr717': 152,
#          'ddk': 151,
#          'Lucky23': 149,
#          'dst': 144,
#          'Legion64': 135,
#          'chaosrd': 135,
#          'capeBoysNoob': 134,
#          'Av3stan': 119,
#          'Wildling': 102,
#          'Chacha': 102,
#          'Amadeus': 97,
#          'Simba': 90,
#          'Satanicwarhamster': 87,
#          'dragonstar1233': 77,
#          'Alexander8507': 76,
#          'scarecrow': 75,
#          'Apu': 75,
#          'FraGSitauX': 68,
#          'sid': 68,
#          'drgameher': 65,
#          'panda': 64,
#          'Fish Curry': 63,
#          'keysersoze': 58,
#          'The SILENT MONK': 55,
#          'Dranzer13': 47,
#          'harshit': 44,
#          'steelskin': 43,
#          'ucchash94': 41,
#          'link.chaos': 38,
#          'Comrade': 37,
#          'Nicco': 36,
#          'Phantom': 35,
#          'Vegeta9999': 34,
#          'Garam Aadmi': 33,
#          'jOkEs On YoU': 32,
#          'Rohan': 31,
#          'SMR': 28,
#          'ThirtiethBog219': 25,
#          'Storm': 22,
#          'himansu': 20,
#          'motava': 20,
#          'Yugeengimli': 19,
#          'WackieChan': 18,
#          'Anca': 18,
#          'Diabloz': 18,
#          'Jesterkori': 17,
#          'Slayer': 15,
#          'LlamaToast 🏴☠': 14,
#          'shrp': 13,
#          '.thealexander': 13,
#          'Hitman': 13,
#          'gauthambhandary09737': 12,
#          'billuboss': 12,
#          'scytheroxx': 11,
#          'rsalgut': 11,
#          'lottery martin': 10,
#          'leo.abnv': 10,
#          'Maximus': 10,
#          'kaos': 10,
#          'andrabi': 9,
#          'MachPatel': 8,
#          'kAPi': 7,
#          'mosaicrezty3247': 7,
#          'NileshJavar': 7,
#          'Fluffy': 6,
#          'Bangbang': 6,
#          'Strider': 6,
#          'vinay24': 5,
#          'rogganwololo': 5,
#          'prabhatsrivastava': 5,
#          'MadMax': 5,
#          'prof': 5,
#          'Ikka Stuff': 4,
#          'Sniper': 4,
#          'Mr.LoVe': 4,
#          'old.monk': 3,
#          'Asterix': 3,
#          'HenryX': 3,
#          'meetyrdoom': 3,
#          'bavingelson': 3,
#          'deepak.sharma.ji': 3,
#          'yonemesis5258': 3,
#          'SkuLLXD': 3,
#          'TheHappyBoar': 2,
#          'goko': 2,
#          'threeeyedraven': 2,
#          'avnish1': 2,
#          'BombayGypsy': 2,
#          'vetrierai': 2,
#          'Lifehack': 2,
#          'basshunteraoe': 2,
#          'HistoryNerd': 2,
#          'Shoumo': 2,
#          'riddist': 2,
#          'nemes1s': 1,
#          'Srini Mama': 1,
#          'rafale360': 1,
#          '💥Smokeu4joke': 1,
#          'cyanide': 1,
#          'veralasata': 1,
#          'ch0r': 1,
#          'thaimadz': 1,
#          'FaTaLAxE': 1,
#          'Dinomar': 1,
#          'Zaid Noob': 1,
#          'rk6010': 1,
#          'smvbluestar': 1,
#          'samudragupta2904': 1,
#          'tasmaniandevil21': 1,
#          'WhiteSmith': 1,
#          'stealthyChakram': 1,
#          'saiki07211': 1,
#          'rohan5012': 1,
#          'Beelzebub': 1,
#          'Plan C': 1,
#          'MarjiManRTS': 1,
#          'abhinandankarwa': 1,
#          'bharathkumar539': 1,
#          'eKkO': 1})

# %%
map_df
# Out:
#       match_id        date year_month                       map            w1  \
# 22     1059327  2024-11-03    2024-11  Land Nomad (Random civs)         Thiru
# 39     1058340  2024-11-02    2024-11  Land Nomad (Random civs)      DOOMSTER
# 55     1057442  2024-11-01    2024-11  Land Nomad (Random civs)  peppapig2108
# 75     1054660  2024-10-28    2024-10  Land Nomad (Random civs)        Plan B
# 98     1053523  2024-10-27    2024-10  Land Nomad (Random civs)  peppapig2108
# ...        ...         ...        ...                       ...           ...
# 7946    474646  2022-07-05    2022-07  Land Nomad (Random civs)        Mirror
# 7978    472874  2022-07-01    2022-07  Land Nomad (Random civs)           ddk
# 8030    470022  2022-06-23    2022-06  Land Nomad (Random civs)          addu
# 8054    468780  2022-06-20    2022-06  Land Nomad (Random civs)        Mirror
# 8063    468050  2022-06-18    2022-06  Land Nomad (Random civs)          addu
#
#                   w2           w3              w4        l1          l2  ...  \
# 22             Royal   New Player       billuboss   Saracen    dopefish  ...
# 39           AMMbush      THUNDER      BraveHeart      addu    RedViper  ...
# 55    Shadeslayer II        TRush     Garam Aadmi      MODI     THUNDER  ...
# 75             Royal         MODI           TRush  AgentP97        Livi  ...
# 98           Himansu     dopefish           TRush   MrWrong     Saracen  ...
# ...              ...          ...             ...       ...         ...  ...
# 7946             ddk      adirath  Shadeslayer II  noobnoob       Kappa  ...
# 7978         Saracen     FraGStaR         Aragorn   arjya13  Vegeta9999  ...
# 8030         THUNDER  Ju$TK!Dd!nG         adirath     Thiru     arjya13  ...
# 8054          Sargun         Livi     Ju$TK!Dd!nG     Thiru        gelf  ...
# 8063          Mirror     newisyou         adirath     Kappa     Saracen  ...
#
#      w4_nr l1_or  l2_or  l3_or  l4_or  l1_nr  l2_nr  l3_nr  l4_nr    map_only
# 22      96  1507    904    699    696   1486    883    678    675  Land Nomad
# 39     920  2813   1699   1627    569   2792   1678   1606    548  Land Nomad
# 55     536  1419   1075    816    643   1398   1054    795    622  Land Nomad
# 75     640  1879   1349   1290    684   1858   1328   1269    663  Land Nomad
# 98     648  1470   1400    667    666   1450   1380    647    646  Land Nomad
# ...    ...   ...    ...    ...    ...    ...    ...    ...    ...         ...
# 7946   873  1816   1676    818    341   1800   1660    802    325  Land Nomad
# 7978   497  1382   1138    633    606   1368   1124    619    592  Land Nomad
# 8030   873  1632   1524   1326    641   1617   1509   1311    626  Land Nomad
# 8054  1097  1649   1367   1035    812   1634   1352   1020    797  Land Nomad
# 8063   764  1659   1344   1167   1030   1641   1326   1149   1012  Land Nomad
#
# [390 rows x 29 columns]

# %%
all_players = list(set(
                    map_df['w1'].values.tolist() +
                    map_df['w2'].values.tolist() +
                    map_df['w3'].values.tolist() +
                    map_df['w4'].values.tolist() +
                    map_df['l1'].values.tolist() +
                    map_df['l2'].values.tolist() +
                    map_df['l3'].values.tolist() +
                    map_df['l4'].values.tolist()
                    ))
all_players = list(filter(pd.notna, all_players))

# %%
stats = []
for player in all_players:
    won = len(map_df[
                        (map_df['w1'] == player) |
                        (map_df['w2'] == player) |
                        (map_df['w3'] == player) |
                        (map_df['w4'] == player)
                        ].index)
    lost = len(map_df[
                        (map_df['l1'] == player) |
                        (map_df['l2'] == player) |
                        (map_df['l3'] == player) |
                        (map_df['l4'] == player)
                        ].index)
    play_rate = round((won+lost) * 100 / player_game_count[player], 2)
    win_rate = round(won * 100 / (won+lost), 2)
    if won+lost > 0:
        stats.append({
            'player': player,
            'total': won+lost,
            'play_rate': play_rate, 
            'won': won,
            'lost': lost,
            'win_rate': win_rate
        })
stats_df = pd.DataFrame(stats).sort_values(by='win_rate', ascending=False)
results = stats_df[stats_df['total'] >= 10].reset_index(drop=True)
results
# Out:
#              player  total  play_rate  won  lost  win_rate
# 0          CrazyGuY     15       1.80   10     5     66.67
# 1              addu     50       2.63   33    17     66.00
# 2             Water     45       5.55   29    16     64.44
# 3          DOOMSTER     22       2.80   14     8     63.64
# 4          Lathkore     16       4.17   10     6     62.50
# 5         HELLRAZER     24       4.26   15     9     62.50
# 6              ABHI     36       4.17   22    14     61.11
# 7        PoinDexter     15       6.79    9     6     60.00
# 8         Afterlife     16       3.98    9     7     56.25
# 9           CHICKEN     52       4.28   29    23     55.77
# 10               OS     27       5.10   15    12     55.56
# 11          Aragorn     18       2.80   10     8     55.56
# 12             MODI    110       4.02   61    49     55.45
# 13          pHANTOM     20       8.47   11     9     55.00
# 14            Thiru     31       4.38   17    14     54.84
# 15   Shadeslayer II     61       6.26   33    28     54.10
# 16        Sephiroth     52       3.54   28    24     53.85
# 17     ForeRuthless     80       4.81   43    37     53.75
# 18         wArDaDdY     84       5.29   45    39     53.57
# 19          Saracen     88       3.15   47    41     53.41
# 20             Livi    103       4.55   55    48     53.40
# 21           Plan B    107       4.72   57    50     53.27
# 22       New Player     92       6.25   49    43     53.26
# 23         dopefish     32       3.14   17    15     53.12
# 24        KhalDrogo     17       3.45    9     8     52.94
# 25        JayMystic     53       4.87   28    25     52.83
# 26          MrWrong     46       4.86   24    22     52.17
# 27          AMMbush     71       4.62   37    34     52.11
# 28     peppapig2108     48       4.62   25    23     52.08
# 29          Himansu     79       6.12   41    38     51.90
# 30       BraveHeart     83       5.85   43    40     51.81
# 31          adirath    193       4.87  100    93     51.81
# 32         newisyou    119       4.26   61    58     51.26
# 33          Avenger     55       5.33   28    27     50.91
# 34          THUNDER     57       5.74   29    28     50.88
# 35         FraGStaR     81       4.29   41    40     50.62
# 36            AsOcA     14       6.25    7     7     50.00
# 37        Delusion9     40       3.95   19    21     47.50
# 38  talentbutnofarm     32       6.12   15    17     46.88
# 39            Royal     54       5.10   25    29     46.30
# 40       Deadkorpse     35       3.95   16    19     45.71
# 41           SuLTaN     65       4.77   29    36     44.62
# 42           Sargun     25       2.99   11    14     44.00
# 43            Blitz     41       4.22   18    23     43.90
# 44         Aragornn     77       6.14   33    44     42.86
# 45           Fenrir     14       4.20    6     8     42.86
# 46            TRush    103       5.16   43    60     41.75
# 47    गुरुत्वाकर्षण     12       5.50    5     7     41.67
# 48       Oldman0007     29       4.25   12    17     41.38
# 49           Mirror     27       2.91   11    16     40.74
# 50      Ju$TK!Dd!nG    140       3.93   57    83     40.71
# 51         Tinikeya     30       3.55   12    18     40.00
# 52          bosedk1     26       3.11   10    16     38.46
# 53          CHARITH     14       3.26    5     9     35.71
# 54            Morty     14       4.23    5     9     35.71
# 55            Valar     44       2.82   15    29     34.09
# 56   raichoooo!!!!!     23       3.48    6    17     26.09
# 57   Sigma Grindset     12       3.24    3     9     25.00
